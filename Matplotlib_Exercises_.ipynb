# %% [markdown]
# <a href="https://colab.research.google.com/github/DevRichan/Matplotlib-Visualization/blob/master/Matplotlib_Exercises_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <a href='https://www.purwadhika.com/'> <img style="height: 200px" src='https://www.dicoding.com/images/original/event/201705181703334cc2c00c0d639e4593a12a55aa4c8103.png' /></a>
# ___
# # Matplotlib Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title('title')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.axis([0,100,0,200])
plt.show()

# %%
##hsl

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()
axes1 = fig.add_axes([0,0,1,1])
axes2 = fig.add_axes([0.2,0.5,.2,.2])

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
axes1.plot(x,y)
axes1.axis([0,100,0,200])
axes1.set_xlabel('x')
axes1.set_ylabel('y')

axes2.plot(x,y)
axes1.axis([0,100,0,200])
axes1.set_xlabel('x')
axes1.set_ylabel('y')
fig

# %%
## hsl

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()
axis1 = fig.add_axes([0,0,1,1]) 
axis2 = fig.add_axes([0.2,0.5,.4,.4])

# %%
#hsl

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
axis1.plot(x,z)
axis1.set_xlabel('x')
axis1.set_ylabel('z')
axis1.axis([0,100,0,10000])

axis2.plot(x,y)
axis2.set_title('zoom')
axis2.set_xlabel('x')
axis2.set_ylabel('y')
axis2.axis([20,22,30,50])

fig

# %%
#hsl

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig, ax = plt.subplots(nrows=1,ncols=2)

# %%
##hsl

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
ax[0].plot(x,y,color='blue',ls='--')
ax[0].axis([0,100,0,200])

ax[1].plot(x,z,color='red')
ax[1].axis([0,100,0,10000])


fig

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,2))
ax[0].plot(x,y,color='blue',lw=5)
ax[0].axis([0,100,0,200])
ax[0].set_xlabel('x')
ax[0].set_xlabel('y')

ax[1].plot(x,z,ls='--',color='red')
ax[1].axis([0,100,0,10000])
ax[1].set_xlabel('x')
ax[1].set_xlabel('y')
plt.show()

# %%
## hsl

# %% [markdown]
# # Great Job!
